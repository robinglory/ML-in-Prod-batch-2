# %%
import os
root_path = os.getcwd()
print(root_path)
img_path = r"C:\Users\ASUS\ML-in-Prod-batch-2\3_Image_Processing_Techniques\test_imgs\test_1.png"
print(img_path)
# Out:
# c:\Users\ASUS\ML-in-Prod-batch-2\3_Image_Processing_Techniques\MyLearning
# C:\Users\ASUS\ML-in-Prod-batch-2\3_Image_Processing_Techniques\test_imgs\test_1.png

# %%
import cv2

# %%
img_ =  cv2.imread(img_path)
if (img_ is not None):
    width,height,channel = img_.shape
    print(width,height)
    print(channel)
else:
    print("Error")
# Out:
# 315 600
# 3

# %%
import matplotlib.pyplot as plt
plt.imshow(img_)

# %%
from PIL import Image
img1 = Image.open(img_path)
plt.imshow(img1)

# %%
bgr_img = img_
rgb_cv_img = cv2.cvtColor(bgr_img, cv2.COLOR_BGR2RGB)
plt.imshow(rgb_cv_img)
plt.imshow(img1)

# %%
print(rgb_cv_img.shape)
# Out:
# (315, 600, 3)

# %%
plt.imshow(rgb_cv_img[:,:,0])
plt.imshow(rgb_cv_img[:,:,2])

# %%
gray_image = cv2.cvtColor(rgb_cv_img,cv2.COLOR_RGB2GRAY)
plt.imshow(gray_image)

# %%
print(gray_image.shape)
# Out:
# (315, 600)

# %% [markdown]
# # Circle Detection

# %%
detected_circles = cv2.HoughCircles(gray_image,  
                   cv2.HOUGH_GRADIENT,dp = 1, minDist  = 2, param1 = 50, 
               param2 = 50, minRadius = 1, maxRadius = 40) 
print(detected_circles)
# Out:
# [[[299.5 156.5  39.4]]]

# %%
import numpy as np
if detected_circles is not None: 
    detected_circles = np.uint16(np.around(detected_circles)) 
    for pt in detected_circles[0, :]:
        a, b, r = pt[0], pt[1], pt[2] 
        cv2.circle(rgb_cv_img, (a, b), r, (0, 255, 0), 2)
plt.imshow(rgb_cv_img)
